# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DATA = pd.read_json(r'/Users/samarthsrivastava/Audio Analysis/TEST/new_framework_results.jsonl', lines=True)

# %%
DATA
# Out:
#                   response_id   status  \
# 0    6a115fff89b6e67de7580902  success
# 1    6a0c622349862db34cc049cc  success
# 2    6a07c92e3e225ec28cb8b0cc  success
# 3    6a0759ff3e225ec28cb8af3c  success
# 4    6a07346f6ed039ac9b962c1a  success
# ..                        ...      ...
# 96   69ff1d0e70c221e8cd4381c7    error
# 97   69fed67070c221e8cd438072    error
# 98   69fe13f74fbc14d05b6a1336    error
# 99   6a0474cd50ad0ff30265c183    error
# 100  6a046ed4f7fdaed8517ab7cb    error
#
#                                                  error  duration_ms  \
# 0                                                  NaN    1177040.0
# 1                                                  NaN    1348480.0
# 2                                                  NaN    1351400.0
# 3                                                  NaN    1251860.0
# 4                                                  NaN     790400.0
# ..                                                 ...          ...
# ...

# %%
DATA.loc[DATA['error'].notna(), ['response_id']]
# Out:
#                   response_id
# 25   6a0181faa86514439424795f
# 26   6a017ece3d364e41d49aabd4
# 27   6a017e7b3f25958de6e354fa
# 28   69ff52f37f77c5b8b7e8845b
# 29   69feee8970c221e8cd4380df
# 30   69fed4e67936a7a136a10a36
# 31   69fcbf0cb083f0862694eb8b
# 32   6a0391eaacbe583da324923f
# 33   69ff1370d152bbe1f8cb9189
# 34   69ff0cc67936a7a136a10b47
# 35   69ff08c77936a7a136a10b37
# 36   69fefefa0b14ae54c650c28c
# 37   69fef4140b14ae54c650c259
# 38   69fedc3d70c221e8cd438094
# 39   69fe2258b083f0862694efdf
# 40   69fdf8864fbc14d05b6a12bd
# 41   69fdf4e7ee77f5b836cda324
# 42   69fdf3b862bc71d9b548cdde
# 43   6a047277d36fc4ec2f546cfa
# 44   6a0471c850ad0ff30265c173
# 45   6a047084268b63455f1df2b6
# 46   6a04703550ad0ff30265c16f
# 47   6a046ffc364e02d361d85a68
# 48   6a046ff9364e02d361d85a67
# 49   6a046f4c364e02d361d85a64
# 50   6a046efd9de93336b4cf1578
# 51   6a046ee1d657140753214e47
# 52   6a046ed89de93336b4cf156c
# 53   6a046ed250ad0ff30265c157
# 54   6a046ed1d657140753214e3e
# ...
