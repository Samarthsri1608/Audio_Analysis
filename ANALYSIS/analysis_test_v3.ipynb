# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA = r"/Users/samarthsrivastava/Audio Analysis/TEST/new_framework_results_v3.jsonl"

# %%
df = pd.read_json(DATA, lines=True)
df
# Out:
#                   response_id   status                         error  \
# 0    6a115fff89b6e67de7580902  success                           NaN
# 1    6a0c622349862db34cc049cc  success                           NaN
# 2    6a07c92e3e225ec28cb8b0cc  success                           NaN
# 3    6a0759ff3e225ec28cb8af3c  success                           NaN
# 4    6a07346f6ed039ac9b962c1a    error  The read operation timed out
# ..                        ...      ...                           ...
# 96   69ff1d0e70c221e8cd4381c7  success                           NaN
# 97   69fed67070c221e8cd438072  success                           NaN
# 98   69fe13f74fbc14d05b6a1336    error  The read operation timed out
# 99   6a0474cd50ad0ff30265c183  success                           NaN
# 100  6a046ed4f7fdaed8517ab7cb  success                           NaN
#
#      duration_ms                                         transcript  \
# 0        1182000  Okay, so I'm a 2024 CS graduate, um, from NIT ...
# ...
